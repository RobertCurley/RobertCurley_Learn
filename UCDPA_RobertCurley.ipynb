# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertCurley/RobertCurley_Learn/blob/main/UCDPA_RobertCurley.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Abstract
#
# Post covid there has been an increase in outdoor activities, I wanted to look at where would the best place be to take advantage of wide range of accommodation with National trials around for walking holidays, To add to this I wanted to see what the best time of year would be to visit based on weather.

# %% [markdown]
# # Data
#
# Dataset being used in **report**
#
# *   *Football Manager 2023 Dataset* which can be viewed: https://www.kaggle.com/datasets/platinum22/foot-ball-manager-2023-dataset
#
# **Above subject to change**

# %% [markdown]
# # Importing
#
# Section covering the importing of the databases

# %%
# Import NumPy Package
import numpy as np

# Import Pandas Package
import pandas as pd

# %% [markdown]
# ## Import *Football Manager 2023 Dataset*

# %%
# Upload CSV file of Football Manager 2023 from laptop

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab7b1a63-6fac-4dab-85c1-cd9918faa22a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab7b1a63-6fac-4dab-85c1-cd9918faa22a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# View FM 2023.csv file in python

FM_2023_df = pd.read_csv("FM 2023.csv") # Changed Name to FM_2023_df
FM_2023_df
# Out:
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# 4          Mohamed Salah   AM/S RL   30  185  187           Egypt
# ...                  ...       ...  ...  ...  ...             ...
# 8447          Joe Ashton       D L   16   45  135         England
# 8448          River Ries         S   17   45  135         Germany
# 8449      Halilcan Doğan       D C   23   45  -75          Turkey
# 8450        Adijat Sefer         S   17   45  135         Germany
# 8451         Linus Urban         S   17   45  135         Germany
#
#                             Club  Corners  Crossing  Dribbling  ...  \
# 0                Manchester City       14        19         15  ...
# ...
